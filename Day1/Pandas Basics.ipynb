# %% [markdown]
# # Pandas

# %% [markdown]
# ## Pandas is an important library used in python , which can perform tasks like acessing and manipulation of structured data

# %%
import pandas as pd

# %% [markdown]
# # Read CSV as a DataFrame- which is the representation of data in a tabular form

# %%
df=pd.read_csv("services.csv")

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
#Check the type of df

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#see all the columns in df
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
type(list(df.columns))
# Out:
# list

# %%
# Check the Data Types of columns

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
# Access a particular colums in df
df["fees"]
# Out:
# 0     $2.50 suggested donation for lunch for age 60 ...
# 1     None. Donations requested of clients who can a...
# 2                                                 None.
# 3     Vary according to income ($5-$90). Cash, check...
# 4         $60 application fee. Cash or checks accepted.
# 5     $55 per year membership dues. Classes have fee...
# 6     $85 per day. Vary according to income for thos...
# 7     Suggested donation of $4.25 per meal for senio...
# 8                                                 None.
# 9                                                 None.
# 10                                                None.
# 11                                                None.
# 12                                                None.
# 13                                                None.
# 14                                                None.
# 15    None for emergency services. Vary for after sc...
# 16                                                None.
# ...

# %%
type(df["fees"])
# Out:
# pandas.core.series.Series

# %%
df[["fees"]]
# Out:
#                                                  fees
# 0   $2.50 suggested donation for lunch for age 60 ...
# 1   None. Donations requested of clients who can a...
# 2                                               None.
# 3   Vary according to income ($5-$90). Cash, check...
# 4       $60 application fee. Cash or checks accepted.
# 5   $55 per year membership dues. Classes have fee...
# 6   $85 per day. Vary according to income for thos...
# 7   Suggested donation of $4.25 per meal for senio...
# 8                                               None.
# 9                                               None.
# 10                                              None.
# 11                                              None.
# 12                                              None.
# 13                                              None.
# 14                                              None.
# 15  None for emergency services. Vary for after sc...
# ...

# %%
type(df[["fees"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#Access more than 1 column at a time

# %%
df["name","fees"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'fees')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# we have to use double brackets to view multi columns [[ ]]
df[["name","fees"]]
# Out:
#                                     name  \
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# ...

# %%
type(df[["name","fees"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Now read data from a table which is available in external website

# %%
# !pip install lxml

# %%
import lxml
urld=pd.read_html("http://www.howstat.com/cricket/Statistics/Batting/BattingMostHundredsVsOneCountry.asp")

# %%
urld
# Out:
# [    0                                                  1
#  0 NaN  Test Cricket - Batting Records and Statistics ...,
#                                                     0
#  0  Test Cricket - Batting Records and Statistics ...,
#                                                     0   1
#  0  Players Scoring Most 100s against One Country ... NaN,
#        0                    1             2             3    4     5   6   \
#  0    NaN               Player       Country        Versus  Mat  Inns  NO
#  1    1.0          D G Bradman     Australia       England   37    63   7
#  2    2.0         S M Gavaskar         India   West Indies   27    48   6
#  3    3.0            J B Hobbs       England     Australia   41    71   4
#  4    4.0        S R Tendulkar         India     Australia   39    74   8
#  5    5.0         S P D Smith*     Australia       England   32    56   5
#  6    6.0       K C Sangakkara     Sri Lanka      Pakistan   23    45   6
# ...

# %%
type(urld)
# Out:
# list

# %%
len(urld)
# Out:
# 5

# %%
urld[3]
# Out:
#       0                    1             2             3    4     5   6   \
# 0    NaN               Player       Country        Versus  Mat  Inns  NO
# 1    1.0          D G Bradman     Australia       England   37    63   7
# 2    2.0         S M Gavaskar         India   West Indies   27    48   6
# 3    3.0            J B Hobbs       England     Australia   41    71   4
# 4    4.0        S R Tendulkar         India     Australia   39    74   8
# 5    5.0         S P D Smith*     Australia       England   32    56   5
# 6    6.0       K C Sangakkara     Sri Lanka      Pakistan   23    45   6
# 7    7.0            S R Waugh     Australia       England   46    73  18
# 8    8.0         G S A Sobers   West Indies       England   36    61   8
# 9    9.0       R B Richardson   West Indies     Australia   29    48   4
# 10  10.0        S R Tendulkar         India     Sri Lanka   25    36   3
# 11  11.0             B C Lara   West Indies     Australia   30    56   2
# ...

# %% [markdown]
# # Now let's save the above data to a csv file

# %%
urld[3].to_csv("crick.csv",header=Fa)
