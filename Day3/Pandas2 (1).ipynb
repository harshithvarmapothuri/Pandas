# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
a=df["Name"][1:10]

# %%
b=df["Name"][23:37]

# %%
a+b
# Out:
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# Name: Name, dtype: object

# %%
a.append(b)
# Out:
# /tmp/ipykernel_95/2735396570.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a.append(b)
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 23                         Sloper, Mr. William Thompson
# 24                        Palsson, Miss. Torborg Danira
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26                              Emir, Mr. Farred Chehab
# 27                       Fortune, Mr. Charles Alexander
# ...

# %%
dj=df.copy()

# %%
dj
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dj.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dj.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dj.fillna("Harshith",inplace=True)

# %%
dj
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male      22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      38.0
# 2                               Heikkinen, Miss. Laina  female      26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      35.0
# 4                             Allen, Mr. William Henry    male      35.0
# ..                                                 ...     ...       ...
# ...

# %%
df.dropna(inplace=True,axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
d={
    "a":[1,2,3,4,5],
    "b":[6,7,8,9,10]
}

# %%
pd.DataFrame(d)
# Out:
#    a   b
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.set_index("Name")
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.groupby("Pclass").mean()
# Out:
# /tmp/ipykernel_95/3573772437.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").mean()
#         PassengerId  Survived     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  0.615071  0.393075  13.675550

# %%
df.groupby("Pclass").mean()["Fare"]
# Out:
# /tmp/ipykernel_95/1401337907.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").mean()["Fare"]
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.groupby("Pclass").mean()[["Fare","Parch"]]
# Out:
# /tmp/ipykernel_95/3060927889.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").mean()[["Fare","Parch"]]
#              Fare     Parch
# Pclass
# 1       84.154687  0.356481
# 2       20.662183  0.380435
# 3       13.675550  0.393075

# %%
d1={
"key1":[1,2,3,4,5,6],
"key2":[1,2,5,7,3,9],
"key3":[3,5,1,2,6,7]
}

# %%
d2={
"key1":[1,7,3,9,3,8],
"key4":[2,1,4,0,6,1],
"key5":[9,1,8,3,2,4]
}

# %%
d1=pd.DataFrame(d1)
d2=pd.DataFrame(d2)

# %%
d1
# Out:
#    key1  key2  key3
# 0     1     1     3
# 1     2     2     5
# 2     3     5     1
# 3     4     7     2
# 4     5     3     6
# 5     6     9     7

# %%
d2
# Out:
#    key1  key4  key5
# 0     1     2     9
# 1     7     1     1
# 2     3     4     8
# 3     9     0     3
# 4     3     6     2
# 5     8     1     4

# %%
pd.merge(d1,d2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     1     3     2     9
# 1     3     5     1     4     8
# 2     3     5     1     6     2

# %%
pd.merge(d1,d2,how="left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     1     3   2.0   9.0
# 1     2     2     5   NaN   NaN
# 2     3     5     1   4.0   8.0
# 3     3     5     1   6.0   2.0
# 4     4     7     2   NaN   NaN
# 5     5     3     6   NaN   NaN
# 6     6     9     7   NaN   NaN

# %%
pd.merge(d1,d2,how="right")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   1.0   3.0     2     9
# 1     7   NaN   NaN     1     1
# 2     3   5.0   1.0     4     8
# 3     9   NaN   NaN     0     3
# 4     3   5.0   1.0     6     2
# 5     8   NaN   NaN     1     4

# %%
pd.merge(d1,d2,how="outer")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   1.0   3.0   2.0   9.0
# 1     2   2.0   5.0   NaN   NaN
# 2     3   5.0   1.0   4.0   8.0
# 3     3   5.0   1.0   6.0   2.0
# 4     4   7.0   2.0   NaN   NaN
# 5     5   3.0   6.0   NaN   NaN
# 6     6   9.0   7.0   NaN   NaN
# 7     7   NaN   NaN   1.0   1.0
# 8     9   NaN   NaN   0.0   3.0
# 9     8   NaN   NaN   1.0   4.0

# %%
pd.merge(d1,d2,how="cross")
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     1     3       1     2     9
# 1        1     1     3       7     1     1
# 2        1     1     3       3     4     8
# 3        1     1     3       9     0     3
# 4        1     1     3       3     6     2
# 5        1     1     3       8     1     4
# 6        2     2     5       1     2     9
# 7        2     2     5       7     1     1
# 8        2     2     5       3     4     8
# 9        2     2     5       9     0     3
# 10       2     2     5       3     6     2
# 11       2     2     5       8     1     4
# 12       3     5     1       1     2     9
# 13       3     5     1       7     1     1
# 14       3     5     1       3     4     8
# 15       3     5     1       9     0     3
# 16       3     5     1       3     6     2
# 17       3     5     1       8     1     4
# 18       4     7     2       1     2     9
# 19       4     7     2       7     1     1
# 20       4     7     2       3     4     8
# ...

# %%
d1={
"key1":[1,2,3,4,5,6],
"key2":[1,2,5,7,3,9],
"key3":[3,5,1,2,6,7]
}

# %%
d2={
"key7":[1,7,3,9,3,8],
"key4":[2,1,4,0,6,1],
"key5":[9,1,8,3,2,4]
}

# %%
d1=pd.DataFrame(d1,index=['a','b','c','d','e','f'])

# %%
d1
# Out:
#    key1  key2  key3
# a     1     1     3
# b     2     2     5
# c     3     5     1
# d     4     7     2
# e     5     3     6
# f     6     9     7

# %%
d2=pd.DataFrame(d2,index=['a','l','c','k','e','m'])

# %%
d2
# Out:
#    key7  key4  key5
# a     1     2     9
# l     7     1     1
# c     3     4     8
# k     9     0     3
# e     3     6     2
# m     8     1     4

# %%
d1.join(d2)
# Out:
#    key1  key2  key3  key7  key4  key5
# a     1     1     3   1.0   2.0   9.0
# b     2     2     5   NaN   NaN   NaN
# c     3     5     1   3.0   4.0   8.0
# d     4     7     2   NaN   NaN   NaN
# e     5     3     6   3.0   6.0   2.0
# f     6     9     7   NaN   NaN   NaN

# %%
d1.join(d2,how="left")
# Out:
#    key1  key2  key3  key7  key4  key5
# a     1     1     3   1.0   2.0   9.0
# b     2     2     5   NaN   NaN   NaN
# c     3     5     1   3.0   4.0   8.0
# d     4     7     2   NaN   NaN   NaN
# e     5     3     6   3.0   6.0   2.0
# f     6     9     7   NaN   NaN   NaN

# %%
d1.join(d2,how="right")
# Out:
#    key1  key2  key3  key7  key4  key5
# a   1.0   1.0   3.0     1     2     9
# l   NaN   NaN   NaN     7     1     1
# c   3.0   5.0   1.0     3     4     8
# k   NaN   NaN   NaN     9     0     3
# e   5.0   3.0   6.0     3     6     2
# m   NaN   NaN   NaN     8     1     4

# %%
d1.join(d2,how="outer")
# Out:
#    key1  key2  key3  key7  key4  key5
# a   1.0   1.0   3.0   1.0   2.0   9.0
# b   2.0   2.0   5.0   NaN   NaN   NaN
# c   3.0   5.0   1.0   3.0   4.0   8.0
# d   4.0   7.0   2.0   NaN   NaN   NaN
# e   5.0   3.0   6.0   3.0   6.0   2.0
# f   6.0   9.0   7.0   NaN   NaN   NaN
# k   NaN   NaN   NaN   9.0   0.0   3.0
# l   NaN   NaN   NaN   7.0   1.0   1.0
# m   NaN   NaN   NaN   8.0   1.0   4.0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df["Inr"]=df['Fare'].apply(lambda x: x*82.93)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
def st(x):
    if x<1000:
        return "cheap"
    elif x>=1000 and x<5000:
        return "Mid Range"
    else:
        return "Expensive"

# %%
df["status"]=df["Inr"].apply(st)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df["status"]=="Expensive"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: status, Length: 891, dtype: bool

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
for i in df.iterrows():
    print(i)
    break
# Out:
# (0, PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Inr                           601.2425
# status                           cheap
# Name: 0, dtype: object)

# %%
for i in df.items():
    print(i)
# Out:
# ('PassengerId', 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64)
# ('Survived', 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64)
# ('Pclass', 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64)
# ('Name', 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# ...

# %%
d1
# Out:
#    key1  key2  key3
# a     1     1     3
# b     2     2     5
# c     3     5     1
# d     4     7     2
# e     5     3     6
# f     6     9     7

# %%
d1.reindex(['a','c','d','e','b','f'])
# Out:
#    key1  key2  key3
# a     1     1     3
# c     3     5     1
# d     4     7     2
# e     5     3     6
# b     2     2     5
# f     6     9     7

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh" , "krish","hitesh","navin"]}

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
data.set_index("c",inplace=True)

# %%
data.reset_index()
# Out:
#         c  a  b
# 0    sudh  1  4
# 1   krish  2  5
# 2  hitesh  3  6
# 3   navin  4  7

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh" , "krish","hitesh","navin"]}
df1 = pd.DataFrame(data,index = ['a','b','c','d'])

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1.reindex(['c','a','d','b'])
# Out:
#    a  b       c
# c  3  6  hitesh
# a  1  4    sudh
# d  4  7   navin
# b  2  5   krish

# %%
df2=df1[["a","b"]]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
def sums(x):
    return sum(x)

# %%
df2.apply(sums)
# Out:
# a    10
# b    22
# dtype: int64

# %%
df2.applymap(lambda x:x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1.sort_index()
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1.sort_values("c")
# Out:
#    a  b       c
# c  3  6  hitesh
# b  2  5   krish
# d  4  7   navin
# a  1  4    sudh

# %%
df1.sort_values("c",ascending=False)
# Out:
#    a  b       c
# a  1  4    sudh
# d  4  7   navin
# b  2  5   krish
# c  3  6  hitesh

# %%
pd.set_option("display.max_colwidth" , 1000)
df3 = pd.DataFrame({"desc": ["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.","my name is sudh" , "i use to take data science mastes class"]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             desc
# ...

# %%
df3["len"]=df3["desc"].apply(lambda x: len(x))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             desc  \
# ...

# %%
df3["lenword"]=df3["desc"].apply(lambda x: len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             desc  \
# ...

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1["a"].mean()
# Out:
# 2.5

# %%
df1["a"].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df1["a"].median()
# Out:
# 2.5

# %%
df1["a"].sum()
# Out:
# 10

# %%
df1["a"].min()
# Out:
# 1

# %%
df1["a"].max()
# Out:
# 4

# %%
df1["a"].rolling(window=1).sum()
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# Name: a, dtype: float64

# %%
df1["a"].rolling(window=2).sum()
# Out:
# a    NaN
# b    3.0
# c    5.0
# d    7.0
# Name: a, dtype: float64

# %%
df1["a"].rolling(window=4).sum()
# Out:
# a     NaN
# b     NaN
# c     NaN
# d    10.0
# Name: a, dtype: float64

# %%
dates=pd.date_range(start="2022-01-01",end="2023-08-09")

# %%
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2023-07-31', '2023-08-01', '2023-08-02', '2023-08-03',
#                '2023-08-04', '2023-08-05', '2023-08-06', '2023-08-07',
#                '2023-08-08', '2023-08-09'],
#               dtype='datetime64[ns]', length=586, freq='D')

# %%
dates=pd.DataFrame(dates,columns=["Dates"])

# %%
dates
# Out:
#          Dates
# 0   2022-01-01
# 1   2022-01-02
# 2   2022-01-03
# 3   2022-01-04
# 4   2022-01-05
# ..         ...
# 581 2023-08-05
# 582 2023-08-06
# 583 2023-08-07
# 584 2023-08-08
# 585 2023-08-09
#
# [586 rows x 1 columns]

# %%
dates["yr"]=dates["Dates"].dt.year

# %%
dates
# Out:
#          Dates    yr
# 0   2022-01-01  2022
# 1   2022-01-02  2022
# 2   2022-01-03  2022
# 3   2022-01-04  2022
# 4   2022-01-05  2022
# ..         ...   ...
# 581 2023-08-05  2023
# 582 2023-08-06  2023
# 583 2023-08-07  2023
# 584 2023-08-08  2023
# 585 2023-08-09  2023
#
# [586 rows x 2 columns]

# %%
type(dates["yr"])
# Out:
# pandas.core.series.Series

# %%
dates["yr"].dtypes
# Out:
# dtype('int64')

# %%
dates.dtypes
# Out:
# Dates    datetime64[ns]
# yr                int64
# dtype: object

# %%
dd=pd.Timedelta(hours=5,minutes=5,seconds=5)

# %%
dd
# Out:
# Timedelta('0 days 05:05:05')

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
pd.Categorical(df1["a"])
# Out:
# [1, 2, 3, 4]
# Categories (4, int64): [1, 2, 3, 4]

# %%
v=pd.Categorical(df1["a"])

# %%
v.value_counts()
# Out:
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1["c"].value_counts()
# Out:
# sudh      1
# krish     1
# hitesh    1
# navin     1
# Name: c, dtype: int64
